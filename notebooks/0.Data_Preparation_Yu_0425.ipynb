# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/ty/processed_loan.csv', header=0)
# Out:
# /Users/ty/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (20,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    Unnamed: 0       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0           0  1077501    1296599     5000.0       5000.0           4975.0
# 1           1  1077430    1314167     2500.0       2500.0           2500.0
# 2           2  1077175    1313524     2400.0       2400.0           2400.0
# 3           3  1076863    1277178    10000.0      10000.0          10000.0
# 4           4  1075358    1311748     3000.0       3000.0           3000.0
#
#          term  int_rate  installment grade     ...      open_rv_12m  \
# 0   36 months     10.65       162.87     B     ...              NaN
# 1   60 months     15.27        59.83     C     ...              NaN
# 2   36 months     15.96        84.33     C     ...              NaN
# 3   36 months     13.49       339.31     C     ...              NaN
# 4   60 months     12.69        67.79     B     ...              NaN
#
#   open_rv_24m max_bal_bc all_util  total_rev_hi_lim inq_fi total_cu_tl  \
# ...

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'id', u'member_id', u'loan_amnt', u'funded_amnt',
#        u'funded_amnt_inv', u'term', u'int_rate', u'installment', u'grade',
#        u'sub_grade', u'emp_title', u'emp_length', u'home_ownership',
#        u'annual_inc', u'verification_status', u'issue_d', u'loan_status',
#        u'pymnt_plan', u'url', u'desc', u'purpose', u'title', u'zip_code',
#        u'addr_state', u'dti', u'delinq_2yrs', u'earliest_cr_line',
#        u'inq_last_6mths', u'mths_since_last_delinq', u'mths_since_last_record',
#        u'open_acc', u'pub_rec', u'revol_bal', u'revol_util', u'total_acc',
#        u'initial_list_status', u'out_prncp', u'out_prncp_inv', u'total_pymnt',
#        u'total_pymnt_inv', u'total_rec_prncp', u'total_rec_int',
#        u'total_rec_late_fee', u'recoveries', u'collection_recovery_fee',
#        u'last_pymnt_d', u'last_pymnt_amnt', u'next_pymnt_d',
#        u'last_credit_pull_d', u'collections_12_mths_ex_med',
# ...

# %%
data.issued_month.value_counts()
# Out:
# Oct    111971
# Jul     95499
# Nov     88081
# Dec     80420
# Aug     76522
# Apr     70214
# May     67929
# Jun     63874
# Jan     62825
# Sep     62194
# Mar     56102
# Feb     51748
# Name: issued_month, dtype: int64

# %%
data.issued_month[data.issued_month=='Jan']='1'
data.issued_month[data.issued_month=='Feb']='2'
data.issued_month[data.issued_month=='Mar']='3'
data.issued_month[data.issued_month=='Apr']='4'
data.issued_month[data.issued_month=='May']='5'
data.issued_month[data.issued_month=='Jun']='6'
data.issued_month[data.issued_month=='Jul']='7'
data.issued_month[data.issued_month=='Aug']='8'
data.issued_month[data.issued_month=='Sep']='9'
data.issued_month[data.issued_month=='Oct']='10'
data.issued_month[data.issued_month=='Nov']='11'
data.issued_month[data.issued_month=='Dec']='12'
# Out:
# /Users/ty/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/ty/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/ty/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
d3_data=data[['loan_amnt','funded_amnt','annual_inc','emp_length','home_ownership','int_rate','grade','sub_grade','purpose','addr_state','issued_month', 'issued_year']]

# %%
d3_data.issued_month = d3_data.issued_month.astype(str)
d3_data.issued_year = d3_data.issued_year.astype(str)
# Out:
# /Users/ty/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:2999: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
d3_data['date']=d3_data.issued_month+'/1/'+d3_data.issued_year
# Out:
# /Users/ty/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
d3_data
# Out:
#         loan_amnt  funded_amnt  annual_inc emp_length home_ownership  \
# 0          5000.0       5000.0    24000.00  10+ years           RENT
# 1          2500.0       2500.0    30000.00   < 1 year           RENT
# 2          2400.0       2400.0    12252.00  10+ years           RENT
# 3         10000.0      10000.0    49200.00  10+ years           RENT
# 4          3000.0       3000.0    80000.00     1 year           RENT
# 5          5000.0       5000.0    36000.00    3 years           RENT
# 6          7000.0       7000.0    47004.00    8 years           RENT
# 7          3000.0       3000.0    48000.00    9 years           RENT
# 8          5600.0       5600.0    40000.00    4 years            OWN
# 9          5375.0       5375.0    15000.00   < 1 year           RENT
# 10         6500.0       6500.0    72000.00    5 years            OWN
# 11        12000.0      12000.0    75000.00  10+ years            OWN
# 12         9000.0       9000.0    30000.00   < 1 year           RENT
# ...

# %%
d3_data.fillna(0,inplace=True)
d3_data.isnull().sum()
# Out:
# /Users/ty/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:2852: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# loan_amnt         0
# funded_amnt       0
# annual_inc        0
# emp_length        0
# home_ownership    0
# int_rate          0
# grade             0
# sub_grade         0
# purpose           0
# addr_state        0
# issued_month      0
# issued_year       0
# date              0
# dtype: int64

# %%
d3_data.to_csv('d3_data_full.csv')

# %%
d3_data[['loan_amnt','grade','date']].to_csv('d3_data_streamgraph.csv')

# %%
d3_data.grade.value_counts()
# Out:
# B    254535
# C    245860
# A    148202
# D    139542
# E     70705
# F     23046
# G      5489
# Name: grade, dtype: int64

# %%
d3_data_streamgraph=d3_data[['loan_amnt','grade','date']]

# %%
a=d3_data_streamgraph.groupby(['grade','date']).sum()

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.to_csv('d3_data_streamgraph_processed.csv')

# %%
a=d3_data_streamgraph.groupby(['grade','date']).count()

# %%
a
# Out:
#                  loan_amnt
# grade date
# A     1/1/2008          45
#       1/1/2009          61
#       1/1/2010         136
#       1/1/2011         403
#       1/1/2012         702
#       1/1/2013         905
#       1/1/2014        2394
#       1/1/2015        6034
#       10/1/2007          8
#       10/1/2008         21
#       10/1/2009        127
#       10/1/2010        308
#       10/1/2011        701
#       10/1/2012       1065
#       10/1/2013       1628
#       10/1/2014       7064
#       10/1/2015       8746
#       11/1/2007         11
#       11/1/2008         33
#       11/1/2009        148
#       11/1/2010        358
#       11/1/2011        597
#       11/1/2012        976
#       11/1/2013       2626
#       11/1/2014       4100
#       11/1/2015       6514
#       12/1/2007         12
#       12/1/2008         48
#       12/1/2009        139
#       12/1/2010        397
# ...                    ...
# G     6/1/2013          89
#       6/1/2014         128
# ...

# %%
d3_data_2=data[['loan_amnt','grade','purpose','addr_state','issued_month']]

# %%
d3_data_2
# Out:
#         loan_amnt grade             purpose addr_state issued_month
# 0          5000.0     B         credit_card         AZ           12
# 1          2500.0     C                 car         GA           12
# 2          2400.0     C      small_business         IL           12
# 3         10000.0     C               other         CA           12
# 4          3000.0     B               other         OR           12
# 5          5000.0     A             wedding         AZ           12
# 6          7000.0     C  debt_consolidation         NC           12
# 7          3000.0     E                 car         CA           12
# 8          5600.0     F      small_business         CA           12
# 9          5375.0     B               other         TX           12
# 10         6500.0     C  debt_consolidation         AZ           12
# 11        12000.0     B  debt_consolidation         CA           12
# 12         9000.0     C  debt_consolidation         VA           12
# ...

# %%
d3_data.issued_month = d3_data.issued_month.astype(str)
d3_data['date']=d3_data.issued_month+'/1'
# Out:
# /Users/ty/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
a = d3_data[d3_data.issued_year=='2015']
b=a[['loan_amnt','grade','date']].rename(columns={'grade':'key','loan_amnt':'value'})
b.date=b.date.astype(str)

# %%
b['date']=b.date+'/15'
b
# Out:
#           value key     date
# 466285  35000.0   C  12/1/15
# 466286   8650.0   A  12/1/15
# 466287   4225.0   C  12/1/15
# 466288  10000.0   C  12/1/15
# 466289  20000.0   B  12/1/15
# 466290  15000.0   B  12/1/15
# 466291  25000.0   A  12/1/15
# 466292   3600.0   C  12/1/15
# 466293  11950.0   C  12/1/15
# 466294  15000.0   A  12/1/15
# 466295  24000.0   B  12/1/15
# 466296  10400.0   F  12/1/15
# 466297  17475.0   C  12/1/15
# 466298  17925.0   D  12/1/15
# 466299  23000.0   B  12/1/15
# 466300   8650.0   E  12/1/15
# 466301   9000.0   B  12/1/15
# 466302  35000.0   C  12/1/15
# 466303   8000.0   B  12/1/15
# 466304  28000.0   A  12/1/15
# 466305  15000.0   B  12/1/15
# 466306   2500.0   D  12/1/15
# 466307  10000.0   A  12/1/15
# 466308  25000.0   B  12/1/15
# 466309  14000.0   B  12/1/15
# 466310  16000.0   C  12/1/15
# 466311   9600.0   A  12/1/15
# 466312  25000.0   C  12/1/15
# 466313  10000.0   B  12/1/15
# 466314  20000.0   A  12/1/15
# ...         ...  ..      ...
# ...

# %%
b.groupby(['key','date']).sum().to_csv('d3_data_2015_streamgraph_totalAmt.csv')

# %%
c = b.groupby(['key','date']).sum()

# %%
c.value.min()
# Out:
# 2569125.0

# %%
a=pd.read_csv('/Users/ty/Desktop/data.csv',header=0)

# %%
results = 
for i in range(0,len(a)):
    a.loc[i]
# Out:
#     key  value     date
# 0    AR   0.10   1/8/13
# 1    AR   0.15   1/9/13
# 2    AR   0.35  1/10/13
# 3    AR   0.38  1/11/13
# 4    AR   0.22  1/12/13
# 5    AR   0.16  1/13/13
# 6    AR   0.07  1/14/13
# 7    AR   0.02  1/15/13
# 8    AR   0.17  1/16/13
# 9    AR   0.33  1/17/13
# 10   AR   0.40  1/18/13
# 11   AR   0.32  1/19/13
# 12   AR   0.26  1/20/13
# 13   AR   0.35  1/21/13
# 14   AR   0.40  1/22/13
# 15   AR   0.32  1/23/13
# 16   AR   0.26  1/24/13
# 17   AR   0.22  1/25/13
# 18   AR   0.16  1/26/13
# 19   AR   0.22  1/27/13
# 20   AR   0.10  1/28/13
# 21   DJ   0.35   1/8/13
# 22   DJ   0.36   1/9/13
# 23   DJ   0.37  1/10/13
# 24   DJ   0.22  1/11/13
# 25   DJ   0.24  1/12/13
# 26   DJ   0.26  1/13/13
# 27   DJ   0.34  1/14/13
# 28   DJ   0.21  1/15/13
# 29   DJ   0.18  1/16/13
# ..   ..    ...      ...
# 96   CG   0.26  1/20/13
# 97   CG   0.35  1/21/13
# 98   CG   0.40  1/22/13
# 99   CG   0.32  1/23/13
# 100  CG   0.26  1/24/13
# 101  CG   0.22  1/25/13
# ...
